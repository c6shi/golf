# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import chromedriver_autoinstaller
import requests
import json

# %% [markdown]
# - The U.S. Open was played June 17-20, 2021
# - Par 71
#
# viz ideas
# - hover over a player's icon (include a pic):
#     - map: highlight the country (other countries lighter) and popup an icon of their college (if available)
#     - line graph: four rounds vs score (cumulative?)
# - compare a bunch of players (in terms of score)
#     - select by country
#     - select by college
#     - select by age
#     - select by position
# - leaderboard
#     - after round #
# - clusters:

# %%
leaderboard_api = 'https://www.golfchannel.com/api/v2/events/19207/leaderboard'
scoreboard_api = 'https://www.golfchannel.com/api/v2/events/19207/scorecard'
pairings_http = 'https://www.golfchannel.com/tours/pga-tour/2021/us-open/tee-times'
leaderboard_r = requests.get(leaderboard_api)
scoreboard_r = requests.get(scoreboard_api)
pairings_r = requests.get(pairings_http)

# %% [raw]
# leaderboard = json.loads(leaderboard_r.text)['result']['golfers']
# leaderboard

# %% [raw]
# leaderboard_df_columns = ['golferId', 'position', 'firstName', 'lastName', 'representsCountryName',
#                           'overallPar', 'totalStrokes', 'leaderboardRounds', 'isAmateur', 'age', 'status']
# leaderboard_df = pd.DataFrame(leaderboard)[leaderboard_df_columns]
# leaderboard_df

# %% [raw]
# notcut = leaderboard_df[leaderboard_df['status'] == '']
# notcut

# %% [raw]
# notcut = notcut.copy()
# notcut['R1'] = notcut['leaderboardRounds'].apply(lambda x: x[0]['roundScore'])
# notcut['R2'] = notcut['leaderboardRounds'].apply(lambda x: x[1]['roundScore'])
# notcut['R3'] = notcut['leaderboardRounds'].apply(lambda x: x[2]['roundScore'])
# notcut['R4'] = notcut['leaderboardRounds'].apply(lambda x: x[3]['roundScore'])
# notcut = notcut.drop(columns=['leaderboardRounds', 'status'])
# notcut

# %% [markdown]
# Fill in missing ages

# %% [raw]
# notcut[notcut['age'] == 'Unknown']

# %% [raw]
# missing_ages = {65028: 27, 12103: 50, 71043: 23}
# notcut = notcut.copy()
# for key in missing_ages.keys():
#     notcut.loc[notcut[notcut['golferId'] == key].index, 'age'] = missing_ages[key]
#
# notcut['age'] = notcut['age'].astype(int)

# %% [raw]
# # ready to join
# notcut

# %% [raw]
# # ready to join
# round3_pairings = pd.read_csv("round3_pairings.csv")
# round4_pairings = pd.read_csv("round4_pairings.csv")
# colleges = pd.read_csv("colleges.csv")

# %% [raw]
# full = notcut.merge(round3_pairings, left_on=['firstName', 'lastName'], right_on=['firstName', 'lastName'])
# full = full.rename(columns={'pairing': 'R3_pairing'})
# full = full.merge(round4_pairings, left_on=['firstName', 'lastName'], right_on=['firstName', 'lastName'])
# full = full.rename(columns={'pairing': 'R4_pairing'})
# full = full.merge(colleges, how='left')
# full

# %% [raw]
# full['name'] = full['firstName'] + ' ' + full['lastName']
# full

# %% [raw]
# clean = full
# clean = clean.drop(columns=['firstName', 'lastName', 'isAmateur', 'totalStrokes'])
# clean = clean.rename(columns={'representsCountryName': 'country', 'college (at graduation)': 'college'})
# clean = clean[['golferId', 'position', 'name', 'country', 'age', 'overallPar', 'R1', 'R2', 'R3', 'R4',
#               'R3_pairing', 'R4_pairing', 'college']]
# clean

# %% [raw]
# full.to_csv("full.csv", index=False)
# clean.to_csv("clean.csv", index=False)

# %%
clean = pd.read_csv("clean.csv")
clean
# Out:
#     golferId position               name        country  age  overallPar  R1  \
# 0      58207        1           Jon Rahm          Spain   28          -6  69
# 1      21550        2   Louis Oosthuizen   South Africa   40          -5  67
# 2      34793        3     Harris English  United States   33          -3  72
# 3      56859       T4    Guido Migliozzi          Italy   26          -2  71
# 4      53772       T4      Brooks Koepka  United States   33          -2  69
# ..       ...      ...                ...            ...  ...         ...  ..
# 66     40528      T65        Shane Lowry        Ireland   36          13  72
# 67     71043      T68     Wilco Nienaber   South Africa   23          14  72
# 68     67233      T68  Kyle Westmoreland  United States   31          14  71
# 69     18572      T70       Jimmy Walker  United States   44          19  74
# 70     32383      T70       Fabián Gómez      Argentina   44          19  70
#
#     R2  R3  R4  R3_pairing  R4_pairing                          college
# 0   70  72  67          33          32         Arizona State University
# 1   71  70  71          34          35                              NaN
# 2   70  71  68          28          26            University of Georgia
# 3   70  73  68          30          22                              NaN
# 4   73  71  69          26          27         Florida State University
# ..  ..  ..  ..         ...         ...                              ...
# 66  74  72  79           2          13  Athlone Institute of Technology
# 67  74  80  72           3           0                              NaN
# 68  73  78  76          18           2  United States Air Force Academy
# 69  72  77  80           1           1                Baylor University
# 70  76  78  79           3           1                              NaN
#
# [71 rows x 13 columns]

# %%
scoreboard = json.loads(scoreboard_r.text)
scoreboard
# Out:
# {'scorecards': [{'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 61890,
#    'round': 1,
#    'out': 34,
#    'in': 42,
#    'total': 76,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '3', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '2', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '7', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '6', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '6', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 12875,
#    'round': 1,
#    'out': 36,
#    'in': 34,
#    'total': 70,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 35,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '3',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '6', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '2', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 61556,
#    'round': 1,
#    'out': 34,
#    'in': 37,
#    'total': 71,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 62,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '2', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 36490,
#    'round': 1,
#    'out': 37,
#    'in': 39,
#    'total': 76,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 13567,
#    'round': 1,
#    'out': 37,
#    'in': 37,
#    'total': 74,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '6', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 21546,
#    'round': 1,
#    'out': 39,
#    'in': 41,
#    'total': 80,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '7', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '6', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 40566,
#    'round': 1,
#    'out': 37,
#    'in': 37,
#    'total': 74,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 26,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '6', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 54682,
#    'round': 1,
#    'out': 38,
#    'in': 39,
#    'total': 77,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '6',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '2', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '5', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 32383,
#    'round': 1,
#    'out': 35,
#    'in': 35,
#    'total': 70,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 70,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '3',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '3', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '2', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 40761,
#    'round': 1,
#    'out': 39,
#    'in': 37,
#    'total': 76,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '6', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 58646,
#    'round': 1,
#    'out': 35,
#    'in': 36,
#    'total': 71,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 23244,
#    'round': 1,
#    'out': 38,
#    'in': 37,
#    'total': 75,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 57,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '3', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '6', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 40811,
#    'round': 1,
#    'out': 33,
#    'in': 37,
#    'total': 70,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 31,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '3',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '3', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 57149,
#    'round': 1,
#    'out': 37,
#    'in': 41,
#    'total': 78,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '2', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 73149,
#    'round': 1,
#    'out': 37,
#    'in': 36,
#    'total': 73,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 60169,
#    'round': 1,
#    'out': 38,
#    'in': 34,
#    'total': 72,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 71043,
#    'round': 1,
#    'out': 36,
#    'in': 36,
#    'total': 72,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 68,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '2', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 56859,
#    'round': 1,
#    'out': 36,
#    'in': 35,
#    'total': 71,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 4,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '3', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 30560,
#    'round': 1,
#    'out': 33,
#    'in': 34,
#    'total': 67,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 13,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '3', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '2', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 54053,
#    'round': 1,
#    'out': 36,
#    'in': 37,
#    'total': 73,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 15,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '6', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '3', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 34793,
#    'round': 1,
#    'out': 38,
#    'in': 34,
#    'total': 72,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 3,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '3', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 24377,
#    'round': 1,
#    'out': 35,
#    'in': 37,
#    'total': 72,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 19,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '3', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '3', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 39840,
#    'round': 1,
#    'out': 38,
#    'in': 34,
#    'total': 72,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 50,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 65800,
#    'round': 1,
#    'out': 34,
#    'in': 36,
#    'total': 70,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 15,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '3',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '3', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '5', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '3', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '3', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '6', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 12874,
#    'round': 1,
#    'out': 34,
#    'in': 34,
#    'total': 68,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 13,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '3',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '3', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '2', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 12055,
#    'round': 1,
#    'out': 36,
#    'in': 40,
#    'total': 76,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 9999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '2', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '6', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 40528,
#    'round': 1,
#    'out': 36,
#    'in': 36,
#    'total': 72,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 65,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '3', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '7', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 61683,
#    'round': 1,
#    'out': 38,
#    'in': 37,
#    'total': 75,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 4,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '3', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '6', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 40949,
#    'round': 1,
#    'out': 37,
#    'in': 36,
#    'total': 73,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 19,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 568},
#     {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446},
#     {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 53772,
#    'round': 1,
#    'out': 36,
#    'in': 33,
#    'total': 69,
#    'startHole': 10,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 4,
#    'scores': [{'hole': 10,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 449},
#     {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '3', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 434},
# ...
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '3', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '3', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 66512,
#    'round': 4,
#    'out': 35,
#    'in': 39,
#    'total': 74,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 57,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '5', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 61556,
#    'round': 4,
#    'out': 36,
#    'in': 39,
#    'total': 75,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 62,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 11134,
#    'round': 4,
#    'out': 35,
#    'in': 40,
#    'total': 75,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 62,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '5', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '6', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 67233,
#    'round': 4,
#    'out': 38,
#    'in': 38,
#    'total': 76,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 68,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '3', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '4', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '3', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 21242,
#    'round': 4,
#    'out': 36,
#    'in': 39,
#    'total': 75,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 65,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '6', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '3', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 18572,
#    'round': 4,
#    'out': 39,
#    'in': 41,
#    'total': 80,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 70,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '5', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 32383,
#    'round': 4,
#    'out': 40,
#    'in': 39,
#    'total': 79,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 70,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '5',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '3', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '4', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '6', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '5', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '5', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '5', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '6', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 71043,
#    'round': 4,
#    'out': 34,
#    'in': 38,
#    'total': 72,
#    'startHole': 1,
#    'holesPlayed': 18,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 68,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '4',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '2', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '4', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '4', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '5', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '5', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '4', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '5', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]},
#   {'type': '',
#    'eventId': 19207,
#    'eventName': 'U.S. Open',
#    'golferId': 66448,
#    'round': 4,
#    'out': 0,
#    'in': 0,
#    'total': 0,
#    'startHole': 0,
#    'holesPlayed': 0,
#    'matchId': None,
#    'courseKey': 1212,
#    'stats': None,
#    'position': 999,
#    'scores': [{'hole': 1,
#      'holeOrder': 1,
#      'par': 4,
#      'score': '',
#      'yardage': 446},
#     {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '', 'yardage': 387},
#     {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '', 'yardage': 195},
#     {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '', 'yardage': 486},
#     {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '', 'yardage': 452},
#     {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '', 'yardage': 515},
#     {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '', 'yardage': 460},
#     {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '', 'yardage': 173},
#     {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '', 'yardage': 609},
#     {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '', 'yardage': 449},
#     {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '', 'yardage': 222},
#     {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '', 'yardage': 501},
#     {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '', 'yardage': 612},
#     {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '', 'yardage': 434},
#     {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '', 'yardage': 513},
#     {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '', 'yardage': 223},
#     {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '', 'yardage': 440},
#     {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '', 'yardage': 568}]}]}

# %%
for i in scoreboard['scorecards']:
    if i['golferId'] == 58207:
        print(i, '\n')
# Out:
# {'type': '', 'eventId': 19207, 'eventName': 'U.S. Open', 'golferId': 58207, 'round': 1, 'out': 34, 'in': 35, 'total': 69, 'startHole': 10, 'holesPlayed': 18, 'matchId': None, 'courseKey': 1212, 'stats': None, 'position': 1, 'scores': [{'hole': 10, 'holeOrder': 1, 'par': 4, 'score': '3', 'yardage': 449}, {'hole': 11, 'holeOrder': 2, 'par': 3, 'score': '4', 'yardage': 222}, {'hole': 12, 'holeOrder': 3, 'par': 4, 'score': '5', 'yardage': 501}, {'hole': 13, 'holeOrder': 4, 'par': 5, 'score': '4', 'yardage': 612}, {'hole': 14, 'holeOrder': 5, 'par': 4, 'score': '3', 'yardage': 434}, {'hole': 15, 'holeOrder': 6, 'par': 4, 'score': '5', 'yardage': 513}, {'hole': 16, 'holeOrder': 7, 'par': 3, 'score': '3', 'yardage': 223}, {'hole': 17, 'holeOrder': 8, 'par': 4, 'score': '4', 'yardage': 440}, {'hole': 18, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 568}, {'hole': 1, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 446}, {'hole': 2, 'holeOrder': 11, 'par': 4, 'score': '3', 'yardage': 387}, {'hole': 3, 'holeOrder': 12, 'par': 3, 'score': '3', 'yardage': 195}, {'hole': 4, 'holeOrder': 13, 'par': 4, 'score': '4', 'yardage': 486}, {'hole': 5, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 452}, {'hole': 6, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 515}, {'hole': 7, 'holeOrder': 16, 'par': 4, 'score': '4', 'yardage': 460}, {'hole': 8, 'holeOrder': 17, 'par': 3, 'score': '3', 'yardage': 173}, {'hole': 9, 'holeOrder': 18, 'par': 5, 'score': '5', 'yardage': 609}]}
#
# {'type': '', 'eventId': 19207, 'eventName': 'U.S. Open', 'golferId': 58207, 'round': 2, 'out': 35, 'in': 35, 'total': 70, 'startHole': 1, 'holesPlayed': 18, 'matchId': None, 'courseKey': 1212, 'stats': None, 'position': 1, 'scores': [{'hole': 1, 'holeOrder': 1, 'par': 4, 'score': '4', 'yardage': 446}, {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387}, {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195}, {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486}, {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '5', 'yardage': 452}, {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '3', 'yardage': 515}, {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460}, {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173}, {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609}, {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449}, {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222}, {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501}, {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '6', 'yardage': 612}, {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '3', 'yardage': 434}, {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513}, {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223}, {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440}, {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]}
#
# {'type': '', 'eventId': 19207, 'eventName': 'U.S. Open', 'golferId': 58207, 'round': 3, 'out': 36, 'in': 36, 'total': 72, 'startHole': 1, 'holesPlayed': 18, 'matchId': None, 'courseKey': 1212, 'stats': None, 'position': 1, 'scores': [{'hole': 1, 'holeOrder': 1, 'par': 4, 'score': '4', 'yardage': 446}, {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '4', 'yardage': 387}, {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195}, {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '4', 'yardage': 486}, {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452}, {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515}, {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460}, {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '4', 'yardage': 173}, {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '5', 'yardage': 609}, {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '3', 'yardage': 449}, {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222}, {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501}, {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612}, {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '6', 'yardage': 434}, {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513}, {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223}, {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '4', 'yardage': 440}, {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]}
#
# {'type': '', 'eventId': 19207, 'eventName': 'U.S. Open', 'golferId': 58207, 'round': 4, 'out': 33, 'in': 34, 'total': 67, 'startHole': 1, 'holesPlayed': 18, 'matchId': None, 'courseKey': 1212, 'stats': None, 'position': 1, 'scores': [{'hole': 1, 'holeOrder': 1, 'par': 4, 'score': '3', 'yardage': 446}, {'hole': 2, 'holeOrder': 2, 'par': 4, 'score': '3', 'yardage': 387}, {'hole': 3, 'holeOrder': 3, 'par': 3, 'score': '3', 'yardage': 195}, {'hole': 4, 'holeOrder': 4, 'par': 4, 'score': '5', 'yardage': 486}, {'hole': 5, 'holeOrder': 5, 'par': 4, 'score': '4', 'yardage': 452}, {'hole': 6, 'holeOrder': 6, 'par': 4, 'score': '4', 'yardage': 515}, {'hole': 7, 'holeOrder': 7, 'par': 4, 'score': '4', 'yardage': 460}, {'hole': 8, 'holeOrder': 8, 'par': 3, 'score': '3', 'yardage': 173}, {'hole': 9, 'holeOrder': 9, 'par': 5, 'score': '4', 'yardage': 609}, {'hole': 10, 'holeOrder': 10, 'par': 4, 'score': '4', 'yardage': 449}, {'hole': 11, 'holeOrder': 11, 'par': 3, 'score': '3', 'yardage': 222}, {'hole': 12, 'holeOrder': 12, 'par': 4, 'score': '4', 'yardage': 501}, {'hole': 13, 'holeOrder': 13, 'par': 5, 'score': '5', 'yardage': 612}, {'hole': 14, 'holeOrder': 14, 'par': 4, 'score': '4', 'yardage': 434}, {'hole': 15, 'holeOrder': 15, 'par': 4, 'score': '4', 'yardage': 513}, {'hole': 16, 'holeOrder': 16, 'par': 3, 'score': '3', 'yardage': 223}, {'hole': 17, 'holeOrder': 17, 'par': 4, 'score': '3', 'yardage': 440}, {'hole': 18, 'holeOrder': 18, 'par': 5, 'score': '4', 'yardage': 568}]}

# %% [raw]
# # scraping tee times
#
# chromedriver_autoinstaller.install()
# driver = webdriver.Chrome()
# driver.get(pairings_http)

# %% [raw]
# html = driver.page_source
# pairings_bs = BeautifulSoup(html, "html.parser")
# round3 = pairings_bs.find_all("div", attrs={"class": "tee-card"})
# pairings = []
# for card in round3:
#     name = card.find_all("p")[1:]
#     if len(name) > 1:
#         name_only = []
#         for i in name:
#             name_list = i.text.strip().split("\n")
#             one_name = []
#             for j in name_list:
#                 one_name.append(j.strip())
#             name_only.append(one_name)
#     else:
#         name_list = name[0].text.strip().split("\n")
#         name_only = []
#         for j in name_list:
#             name_only.append(j.strip())
#     pairings.append(name_only)
# pairings

# %% [raw]
# round3_pairings_df = pd.DataFrame(columns=['pairing', 'firstName', 'lastName'])
# for (i, k) in enumerate(pairings):
#     if type(k[0]) == str:
#         one_row = pd.DataFrame({'pairing': i, 'firstName': k[0], 'lastName': k[1]}, index=[i])
#         round3_pairings_df = pd.concat([round3_pairings_df, one_row])
#     else:
#         for player in k:
#             one_row = pd.DataFrame({'pairing': i, 'firstName': player[0], 'lastName': player[1]}, index=[i])
#             round3_pairings_df = pd.concat([round3_pairings_df, one_row])
# round3_pairings_df = round3_pairings_df.reset_index(drop=True)
# round3_pairings_df

# %% [raw]
# round3_pairings_df.to_csv("round4_pairings.csv", index=False)
